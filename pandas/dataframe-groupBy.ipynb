# %%
import numpy as n 
import pandas as p

# %%
df = p.read_csv('/Users/ka53/Desktop/ml/Notebooks ML Rus V10/DATA/mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df[df['acceleration'] > 22]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 59   23.0          4          97.0         54    2254          23.5
# 195  29.0          4          85.0         52    2035          22.2
# 196  24.5          4          98.0         60    2164          22.1
# 299  27.2          4         141.0         71    3190          24.8
# 300  23.9          8         260.0         90    3420          22.2
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
#
#      model_year  origin                               name
# 59           72       2                  volkswagen type 3
# 195          76       1                 chevrolet chevette
# 196          76       1                    chevrolet woody
# 299          79       2                        peugeot 504
# 300          79       1  oldsmobile cutlass salon brougham
# 326          80       2                 vw dasher (diesel)
# ...

# %%
df[df['model_year'] >= 82]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 367  28.0          4         112.0         88    2605          19.6
# 368  27.0          4         112.0         88    2640          18.6
# 369  34.0          4         112.0         88    2395          18.0
# 370  31.0          4         112.0         85    2575          16.2
# 371  29.0          4         135.0         84    2525          16.0
# 372  27.0          4         151.0         90    2735          18.0
# 373  24.0          4         140.0         92    2865          16.4
# 374  23.0          4         151.0          ?    3035          20.5
# 375  36.0          4         105.0         74    1980          15.3
# 376  37.0          4          91.0         68    2025          18.2
# 377  31.0          4          91.0         68    1970          17.6
# 378  38.0          4         105.0         63    2125          14.7
# 379  36.0          4          98.0         70    2125          17.3
# ...

# %%
df['model_year'].value_counts() # сколько машин было выпущено в разных годах
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
df.groupby('model_year')

# %%
#### Добавляем вызов метода агрегации. Чтобы использовать объект groupby, нам нужно сообщить pandas, как мы хотим агрегировать данные.
'''
Наиболее частые варианты:

    mean(): среднее значение 
    sum(): сумма значений
    size(): размер группы
    count(): количество элементов
    std(): среднеквадратичное отклонение (standard deviation)
    var(): дисперсия (variance)
    sem(): стандартная ошибка среднего (standard error of the mean)
    describe(): суммарные статистики
    first(): первое значение
    last(): последнее значение
    nth() : n-ое значение, или набор значений если n является списком
    min(): минимальное значение
    max(): максимальное значение
    
'''

# %%
df.groupby('model_year').count()
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          28      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          27      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          29      29            29
# ...

# %%
df.groupby('acceleration').describe()
# Out:
#                mpg                                                      \
#              count   mean       std   min     25%    50%     75%   max
# acceleration
# 8.0            1.0  14.00       NaN  14.0  14.000  14.00  14.000  14.0
# 8.5            2.0  14.50  0.707107  14.0  14.250  14.50  14.750  15.0
# 9.0            1.0  14.00       NaN  14.0  14.000  14.00  14.000  14.0
# 9.5            2.0  15.50  0.707107  15.0  15.250  15.50  15.750  16.0
# 10.0           4.0  14.50  0.577350  14.0  14.000  14.50  15.000  15.0
# ...            ...    ...       ...   ...     ...    ...     ...   ...
# 22.2           2.0  26.45  3.606245  23.9  25.175  26.45  27.725  29.0
# 23.5           1.0  23.00       NaN  23.0  23.000  23.00  23.000  23.0
# 23.7           1.0  43.40       NaN  43.4  43.400  43.40  43.400  43.4
# 24.6           1.0  44.00       NaN  44.0  44.000  44.00  44.000  44.0
# 24.8           1.0  27.20       NaN  27.2  27.200  27.20  27.200  27.2
#
# ...

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.groupby(['model_year','cylinders']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.groupby('weight').max().tail(5)
# Out:
#          mpg  cylinders  displacement horsepower  acceleration  model_year  \
# weight
# 4951    12.0          8         455.0        225          11.0          73
# 4952    12.0          8         429.0        198          11.5          73
# 4955    12.0          8         383.0        180          11.5          71
# 4997    11.0          8         400.0        150          14.0          73
# 5140    13.0          8         400.0        175          12.0          71
#
#         origin                      name
# weight
# 4951         1  buick electra 225 custom
# 4952         1  mercury marquis brougham
# 4955         1         dodge monaco (sw)
# 4997         1          chevrolet impala
# 5140         1       pontiac safari (sw)

# %%
year_cyl = df.groupby(['model_year','cylinders']).max()

# %%
year_cyl
# Out:
#                        mpg  displacement horsepower  weight  acceleration  \
# model_year cylinders
# 70         4          27.0         121.0         95    2672          20.5
#            6          22.0         200.0         97    2833          16.0
#            8          18.0         455.0        225    4732          18.5
# 71         4          35.0         140.0          ?    2408          20.5
#            6          19.0         258.0         88    3439          15.5
#            8          14.0         400.0        180    5140          13.5
# 72         3          19.0          70.0         97    2330          13.5
#            4          28.0         140.0         97    2979          23.5
#            8          17.0         429.0        208    4633          16.0
# 73         3          18.0          70.0         90    2124          13.5
#            4          29.0         140.0         94    2868          21.0
# ...

# %%
year_cyl.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])
