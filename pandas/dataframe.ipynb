# %%
import numpy as n

# %%
import pandas as p

# %%
n.random.seed(101)
mydata = n.random.randint(0,101,(4,3)) # creating 2 arrays
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
mi = ['Latvia','Paris','Augsburg','Milan']
mc = ['La','Fr','Ge']

# %%
df = p.DataFrame(data=mydata,index=mi,columns=mc)
df
# Out:
#           La  Fr  Ge
# Latvia    95  11  81
# Paris     70  63  87
# Augsburg  75   9  77
# Milan     40   4  63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Latvia to Milan
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   La      4 non-null      int64
#  1   Fr      4 non-null      int64
#  2   Ge      4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
pwd
# Out:
# '/Users/ka53/Desktop/ml-practice/pandas'

# %%
ls
# Out:
# 03-Useful-Methods copy.ipynb* series.ipynb
# dataframe.ipynb

# %%
df = p.read_csv('/Users/ka53/Desktop/ml/Notebooks ML Rus V10/DATA/tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns # checking columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(10) # first 10 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail(5) # last five in rows
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679

# %%
df['price_per_person'].head(6)
# Out:
# 0     8.49
# 1     3.45
# 2     7.00
# 3    11.84
# 4     6.15
# 5     6.32
# Name: price_per_person, dtype: float64

# %%
df[['sex','time']].head(3)
# Out:
#       sex    time
# 0  Female  Dinner
# 1    Male  Dinner
# 2    Male  Dinner

# %%
100 * df['tip'].head(3) / df['total_bill'].head(3) # calculating
# Out:
# 0     5.944673
# 1    16.054159
# 2    16.658734
# dtype: float64

# %%
df['tp'] = 100 * df['tip'] / df['total_bill'] # adding new column

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID         tp
# 0  Christy Cunningham  3560325168603410    Sun2959   5.944673
# ...

# %%
df['tp'] = n.round(df['tip']/ df['total_bill'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID    tp
# 0  Christy Cunningham  3560325168603410    Sun2959  0.06
# 1      Douglas Tucker  4478071379779230    Sun4608  0.16
# 2      Travis Walters  6011812112971322    Sun4458  0.17
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.14
# 4        Tonya Carter  4832732618637221    Sun2251  0.15

# %%
df.shape
# Out:
# (244, 12)

# %%
df.drop('tp', axis=1)
df.drop('tip-percent',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 df.drop('tp', axis=1)
# ----> 2 df.drop('tip-percent',axis=1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
#

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID    tp  tip-percent
# 0  Christy Cunningham  3560325168603410    Sun2959  0.06         0.06
# 1      Douglas Tucker  4478071379779230    Sun4608  0.16         0.16
# 2      Travis Walters  6011812112971322    Sun4458  0.17         0.17
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.14         0.14
# 4        Tonya Carter  4832732618637221    Sun2251  0.15         0.15

# %%
df = df.drop(columns=['tp'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip-percent
# 0  Christy Cunningham  3560325168603410    Sun2959         0.06
# 1      Douglas Tucker  4478071379779230    Sun4608         0.16
# 2      Travis Walters  6011812112971322    Sun4458         0.17
# 3    Nathaniel Harris  4676137647685994    Sun5260         0.14
# 4        Tonya Carter  4832732618637221    Sun2251         0.15

# %%
df = df.drop(columns=['tip-percent'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# LINES

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('sex') # transform to index variable = 'sex' , but it will not save
# Out:
#         total_bill   tip smoker   day    time  size  price_per_person  \
# sex
# Female       16.99  1.01     No   Sun  Dinner     2              8.49
# Male         10.34  1.66     No   Sun  Dinner     3              3.45
# Male         21.01  3.50     No   Sun  Dinner     3              7.00
# Male         23.68  3.31     No   Sun  Dinner     2             11.84
# Female       24.59  3.61     No   Sun  Dinner     4              6.15
# ...            ...   ...    ...   ...     ...   ...               ...
# Male         29.03  5.92     No   Sat  Dinner     3              9.68
# Female       27.18  2.00    Yes   Sat  Dinner     2             13.59
# Male         22.67  2.00    Yes   Sat  Dinner     2             11.34
# Male         17.82  1.75     No   Sat  Dinner     2              8.91
# Female       18.78  3.00     No  Thur  Dinner     2              9.39
#
#                 Payer Name         CC Number Payment ID
# sex
# Female  Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df = df.set_index('sex') # know we saved it , we can save only ones , after it will be error

# %%
df.head()
# Out:
#         total_bill   tip smoker  day    time  size  price_per_person  \
# sex
# Female       16.99  1.01     No  Sun  Dinner     2              8.49
# Male         10.34  1.66     No  Sun  Dinner     3              3.45
# Male         21.01  3.50     No  Sun  Dinner     3              7.00
# Male         23.68  3.31     No  Sun  Dinner     2             11.84
# Female       24.59  3.61     No  Sun  Dinner     4              6.15
#
#                 Payer Name         CC Number Payment ID
# sex
# Female  Christy Cunningham  3560325168603410    Sun2959
# Male        Douglas Tucker  4478071379779230    Sun4608
# Male        Travis Walters  6011812112971322    Sun4458
# Male      Nathaniel Harris  4676137647685994    Sun5260
# Female        Tonya Carter  4832732618637221    Sun2251

# %%
df.reset_index() # without parameters , but without saving
# Out:
#         sex  total_bill   tip smoker   day    time  size  price_per_person  \
# 0    Female       16.99  1.01     No   Sun  Dinner     2              8.49
# 1      Male       10.34  1.66     No   Sun  Dinner     3              3.45
# 2      Male       21.01  3.50     No   Sun  Dinner     3              7.00
# 3      Male       23.68  3.31     No   Sun  Dinner     2             11.84
# 4    Female       24.59  3.61     No   Sun  Dinner     4              6.15
# ..      ...         ...   ...    ...   ...     ...   ...               ...
# 239    Male       29.03  5.92     No   Sat  Dinner     3              9.68
# 240  Female       27.18  2.00    Yes   Sat  Dinner     2             13.59
# 241    Male       22.67  2.00    Yes   Sat  Dinner     2             11.34
# 242    Male       17.82  1.75     No   Sat  Dinner     2              8.91
# 243  Female       18.78  3.00     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head()
# Out:
#         total_bill   tip smoker  day    time  size  price_per_person  \
# sex
# Female       16.99  1.01     No  Sun  Dinner     2              8.49
# Male         10.34  1.66     No  Sun  Dinner     3              3.45
# Male         21.01  3.50     No  Sun  Dinner     3              7.00
# Male         23.68  3.31     No  Sun  Dinner     2             11.84
# Female       24.59  3.61     No  Sun  Dinner     4              6.15
#
#                 Payer Name         CC Number Payment ID
# sex
# Female  Christy Cunningham  3560325168603410    Sun2959
# Male        Douglas Tucker  4478071379779230    Sun4608
# Male        Travis Walters  6011812112971322    Sun4458
# Male      Nathaniel Harris  4676137647685994    Sun5260
# Female        Tonya Carter  4832732618637221    Sun2251

# %%
df = df.reset_index() # now we saved it

# %%
df.head()
# Out:
#       sex  total_bill   tip smoker  day    time  size  price_per_person  \
# 0  Female       16.99  1.01     No  Sun  Dinner     2              8.49
# 1    Male       10.34  1.66     No  Sun  Dinner     3              3.45
# 2    Male       21.01  3.50     No  Sun  Dinner     3              7.00
# 3    Male       23.68  3.31     No  Sun  Dinner     2             11.84
# 4  Female       24.59  3.61     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df = df.set_index('sex') # we add again variables 'sex' to column

# %%
df.head()
# Out:
#         total_bill   tip smoker  day    time  size  price_per_person  \
# sex
# Female       16.99  1.01     No  Sun  Dinner     2              8.49
# Male         10.34  1.66     No  Sun  Dinner     3              3.45
# Male         21.01  3.50     No  Sun  Dinner     3              7.00
# Male         23.68  3.31     No  Sun  Dinner     2             11.84
# Female       24.59  3.61     No  Sun  Dinner     4              6.15
#
#                 Payer Name         CC Number Payment ID
# sex
# Female  Christy Cunningham  3560325168603410    Sun2959
# Male        Douglas Tucker  4478071379779230    Sun4608
# Male        Travis Walters  6011812112971322    Sun4458
# Male      Nathaniel Harris  4676137647685994    Sun5260
# Female        Tonya Carter  4832732618637221    Sun2251

# %%
df.iloc[0] # how to get individual line
# Out:
# total_bill                       16.99
# tip                               1.01
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: Female, dtype: object

# %%
df.loc['Male'] # we can get only what in column , so only variable = 'sex'
# Out:
#       total_bill   tip smoker  day    time  size  price_per_person  \
# sex
# Male       10.34  1.66     No  Sun  Dinner     3              3.45
# Male       21.01  3.50     No  Sun  Dinner     3              7.00
# Male       23.68  3.31     No  Sun  Dinner     2             11.84
# Male       25.29  4.71     No  Sun  Dinner     4              6.32
# Male        8.77  2.00     No  Sun  Dinner     2              4.38
# ...          ...   ...    ...  ...     ...   ...               ...
# Male       12.60  1.00    Yes  Sat  Dinner     2              6.30
# Male       32.83  1.17    Yes  Sat  Dinner     2             16.42
# Male       29.03  5.92     No  Sat  Dinner     3              9.68
# Male       22.67  2.00    Yes  Sat  Dinner     2             11.34
# Male       17.82  1.75     No  Sat  Dinner     2              8.91
#
#               Payer Name         CC Number Payment ID
# sex
# Male      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
# i need to remove 'sex' , and put 'tip'

# %%
df = df.reset_index('sex')

# %%
df.head()
# Out:
#       sex  total_bill   tip smoker  day    time  size  price_per_person  \
# 0  Female       16.99  1.01     No  Sun  Dinner     2              8.49
# 1    Male       10.34  1.66     No  Sun  Dinner     3              3.45
# 2    Male       21.01  3.50     No  Sun  Dinner     3              7.00
# 3    Male       23.68  3.31     No  Sun  Dinner     2             11.84
# 4  Female       24.59  3.61     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df = df.set_index('tip')

# %%
df.head()
# Out:
#          sex  total_bill smoker  day    time  size  price_per_person  \
# tip
# 1.01  Female       16.99     No  Sun  Dinner     2              8.49
# 1.66    Male       10.34     No  Sun  Dinner     3              3.45
# 3.50    Male       21.01     No  Sun  Dinner     3              7.00
# 3.31    Male       23.68     No  Sun  Dinner     2             11.84
# 3.61  Female       24.59     No  Sun  Dinner     4              6.15
#
#               Payer Name         CC Number Payment ID
# tip
# 1.01  Christy Cunningham  3560325168603410    Sun2959
# 1.66      Douglas Tucker  4478071379779230    Sun4608
# 3.50      Travis Walters  6011812112971322    Sun4458
# 3.31    Nathaniel Harris  4676137647685994    Sun5260
# 3.61        Tonya Carter  4832732618637221    Sun2251

# %%
df.iloc[0]
# Out:
# sex                             Female
# total_bill                       16.99
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 1.01, dtype: object

# %%
df.loc[1.01]
# Out:
# sex                             Female
# total_bill                       16.99
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 1.01, dtype: object

# %%
df.loc[4.00]
# Out:
#         sex  total_bill smoker   day    time  size  price_per_person  \
# tip
# 4.0    Male       27.20     No  Thur   Lunch     4              6.80
# 4.0    Male       18.28     No  Thur   Lunch     2              9.14
# 4.0    Male       27.28    Yes   Fri  Dinner     2             13.64
# 4.0  Female       14.31    Yes   Sat  Dinner     2              7.16
# 4.0    Male       38.07     No   Sun  Dinner     3             12.69
# 4.0  Female       25.71     No   Sun  Dinner     3              8.57
# 4.0    Male       16.82    Yes   Sun  Dinner     2              8.41
# 4.0  Female        9.60    Yes   Sun  Dinner     2              4.80
# 4.0    Male       23.10    Yes   Sun  Dinner     3              7.70
# 4.0    Male       16.58    Yes  Thur   Lunch     2              8.29
# 4.0    Male       18.71    Yes  Thur   Lunch     3              6.24
# 4.0    Male       20.53    Yes  Thur   Lunch     4              5.13
#
#           Payer Name         CC Number Payment ID
# tip
# ...

# %%
df.loc[[1,5]] # looking for 2 tips 'one' and 'five'
# Out:
#         sex  total_bill smoker   day    time  size  price_per_person  \
# tip
# 1.0  Female        3.07    Yes   Sat  Dinner     1              3.07
# 1.0  Female        5.75    Yes   Fri  Dinner     2              2.88
# 1.0  Female        7.25     No   Sat  Dinner     1              7.25
# 1.0    Male       12.60    Yes   Sat  Dinner     2              6.30
# 5.0  Female       35.26     No   Sun  Dinner     4              8.82
# 5.0    Male       31.27     No   Sat  Dinner     3             10.42
# 5.0    Male       22.23     No   Sun  Dinner     2             11.12
# 5.0  Female       25.28    Yes   Sat  Dinner     2             12.64
# 5.0    Male       32.68    Yes  Thur   Lunch     2             16.34
# 5.0    Male       41.19     No  Thur   Lunch     5              8.24
# 5.0  Female       27.05     No  Thur   Lunch     6              4.51
# 5.0    Male       48.17     No   Sun  Dinner     6              8.03
# ...

# %%
df.loc[1.01]
# Out:
# sex                             Female
# total_bill                       16.99
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 1.01, dtype: object

# %%
df.drop(1.01) # deleting from variable = 'tip' 1.01 , but we did not save it
# Out:
#          sex  total_bill smoker   day    time  size  price_per_person  \
# tip
# 1.66    Male       10.34     No   Sun  Dinner     3              3.45
# 3.50    Male       21.01     No   Sun  Dinner     3              7.00
# 3.31    Male       23.68     No   Sun  Dinner     2             11.84
# 3.61  Female       24.59     No   Sun  Dinner     4              6.15
# 4.71    Male       25.29     No   Sun  Dinner     4              6.32
# ...      ...         ...    ...   ...     ...   ...               ...
# 5.92    Male       29.03     No   Sat  Dinner     3              9.68
# 2.00  Female       27.18    Yes   Sat  Dinner     2             13.59
# 2.00    Male       22.67    Yes   Sat  Dinner     2             11.34
# 1.75    Male       17.82     No   Sat  Dinner     2              8.91
# 3.00  Female       18.78     No  Thur  Dinner     2              9.39
#
#             Payer Name         CC Number Payment ID
# tip
# 1.66    Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.head()
# Out:
#          sex  total_bill smoker  day    time  size  price_per_person  \
# tip
# 1.01  Female       16.99     No  Sun  Dinner     2              8.49
# 1.66    Male       10.34     No  Sun  Dinner     3              3.45
# 3.50    Male       21.01     No  Sun  Dinner     3              7.00
# 3.31    Male       23.68     No  Sun  Dinner     2             11.84
# 3.61  Female       24.59     No  Sun  Dinner     4              6.15
#
#               Payer Name         CC Number Payment ID
# tip
# 1.01  Christy Cunningham  3560325168603410    Sun2959
# 1.66      Douglas Tucker  4478071379779230    Sun4608
# 3.50      Travis Walters  6011812112971322    Sun4458
# 3.31    Nathaniel Harris  4676137647685994    Sun5260
# 3.61        Tonya Carter  4832732618637221    Sun2251

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
# sex                             Female
# total_bill                       16.99
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 1.01, dtype: object

# %%
df.head()
# Out:
#          sex  total_bill smoker  day    time  size  price_per_person  \
# tip
# 1.01  Female       16.99     No  Sun  Dinner     2              8.49
# 1.66    Male       10.34     No  Sun  Dinner     3              3.45
# 3.50    Male       21.01     No  Sun  Dinner     3              7.00
# 3.31    Male       23.68     No  Sun  Dinner     2             11.84
# 3.61  Female       24.59     No  Sun  Dinner     4              6.15
#
#               Payer Name         CC Number Payment ID
# tip
# 1.01  Christy Cunningham  3560325168603410    Sun2959
# 1.66      Douglas Tucker  4478071379779230    Sun4608
# 3.50      Travis Walters  6011812112971322    Sun4458
# 3.31    Nathaniel Harris  4676137647685994    Sun5260
# 3.61        Tonya Carter  4832732618637221    Sun2251

# %%
p.concat([df,p.DataFrame([one_row])]) # adding new row
# Out:
#          sex  total_bill smoker   day    time  size  price_per_person  \
# 1.01  Female       16.99     No   Sun  Dinner     2              8.49
# 1.66    Male       10.34     No   Sun  Dinner     3              3.45
# 3.50    Male       21.01     No   Sun  Dinner     3              7.00
# 3.31    Male       23.68     No   Sun  Dinner     2             11.84
# 3.61  Female       24.59     No   Sun  Dinner     4              6.15
# ...      ...         ...    ...   ...     ...   ...               ...
# 2.00  Female       27.18    Yes   Sat  Dinner     2             13.59
# 2.00    Male       22.67    Yes   Sat  Dinner     2             11.34
# 1.75    Male       17.82     No   Sat  Dinner     2              8.91
# 3.00  Female       18.78     No  Thur  Dinner     2              9.39
# 1.01  Female       16.99     No   Sun  Dinner     2              8.49
#
#               Payer Name         CC Number Payment ID
# 1.01  Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID    tp
# 0  Christy Cunningham  3560325168603410    Sun2959  0.06
# 1      Douglas Tucker  4478071379779230    Sun4608  0.16
# 2      Travis Walters  6011812112971322    Sun4458  0.17
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.14
# 4        Tonya Carter  4832732618637221    Sun2251  0.15

# %%
df[df['tip'] > 5] # condition
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...

# %%
a = df['total_bill'] > 30

# %%
df[a]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# ...

# %%
df[(df['tip'] > 5) & (df['size'] > 3)] # more than 1
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40  5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40  6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27  6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 116       29.93  5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4              5.79
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4              6.47
# ...

# %%
op = ['James Barnes']  #
df[df['Payer Name'].isin(op)]
# Out:
#     total_bill  tip   sex smoker  day    time  size  price_per_person  \
# 47        32.4  6.0  Male     No  Sun  Dinner     4               8.1
#
#       Payer Name         CC Number Payment ID    tp
# 47  James Barnes  3552002592874186    Sun9677  0.19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
#  11  tp                244 non-null    float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 23.0+ KB

# %%
def lf(num):
    return str(num)[-4:]

# %%
lf(343248848384738931234)
# Out:
# '1234'

# %%
df['CC Number'].apply(lf) # we checked cc number last four numbers
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df['CC Number'].apply(lf).head(5)
# Out:
# 0    3410
# 1    9230
# 2    1322
# 3    5994
# 4    7221
# Name: CC Number, dtype: object

# %%
df['total_bill'].mean() # average bill
# Out:
# np.float64(19.78594262295082)

# %%
def yl(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'
    
df['yl'] = df['total_bill'].apply(yl)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID    tp  yl
# 0  Christy Cunningham  3560325168603410    Sun2959  0.06  $$
# 1      Douglas Tucker  4478071379779230    Sun4608  0.16  $$
# 2      Travis Walters  6011812112971322    Sun4458  0.17  $$
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.14  $$
# 4        Tonya Carter  4832732618637221    Sun2251  0.15  $$

# %%
df[df['yl'] == '$$$']
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# ...

# %%
def simple(num):
    return num * 2

simple(8)
# Out:
# 16

# %%
lambda num: num * 2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda num: num * 2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def qualiti(total_bill,tip):
    if tip/total_bill > 0.25:
        return 'good tips'
    else:
        return 'normal tips'
    
qualiti(19,3)
# Out:
# 'normal tips'

# %%
df['tip quality'] = df[['total_bill','tip']].apply(lambda df: qualiti(df['total_bill'],df['tip']),axis=1).head(10)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID    tp  yl  tip quality
# 0  Christy Cunningham  3560325168603410    Sun2959  0.06  $$  normal tips
# 1      Douglas Tucker  4478071379779230    Sun4608  0.16  $$  normal tips
# 2      Travis Walters  6011812112971322    Sun4458  0.17  $$  normal tips
# 3    Nathaniel Harris  4676137647685994    Sun5260  0.14  $$  normal tips
# 4        Tonya Carter  4832732618637221    Sun2251  0.15  $$  normal tips

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
# tp                244.0  1.609426e-01  6.102968e-02  4.000000e-02
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15
# ...

# %%
df.sort_values('price_per_person')
# Out:
#      total_bill    tip     sex smoker  day    time  size  price_per_person  \
# 92         5.75   1.00  Female    Yes  Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes  Sat  Dinner     1              3.07
# 16        10.33   1.67  Female     No  Sun  Dinner     3              3.44
# 1         10.34   1.66    Male     No  Sun  Dinner     3              3.45
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2              3.62
# ..          ...    ...     ...    ...  ...     ...   ...               ...
# 237       32.83   1.17    Male    Yes  Sat  Dinner     2             16.42
# 175       32.90   3.11    Male    Yes  Sun  Dinner     2             16.45
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 179       34.63   3.55    Male    Yes  Sun  Dinner     2             17.32
# 184       40.55   3.00    Male    Yes  Sun  Dinner     2             20.27
#
#            Payer Name         CC Number Payment ID    tp
# ...

# %%
df.sort_values('price_per_person', ascending=False)
# Out:
#      total_bill    tip     sex smoker  day    time  size  price_per_person  \
# 184       40.55   3.00    Male    Yes  Sun  Dinner     2             20.27
# 179       34.63   3.55    Male    Yes  Sun  Dinner     2             17.32
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 175       32.90   3.11    Male    Yes  Sun  Dinner     2             16.45
# 237       32.83   1.17    Male    Yes  Sat  Dinner     2             16.42
# ..          ...    ...     ...    ...  ...     ...   ...               ...
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2              3.62
# 1         10.34   1.66    Male     No  Sun  Dinner     3              3.45
# 16        10.33   1.67  Female     No  Sun  Dinner     3              3.44
# 67         3.07   1.00  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes  Fri  Dinner     2              2.88
#
#            Payer Name         CC Number Payment ID    tp
# ...

# %%
df.sort_values(['price_per_person','tip'])
# Out:
#      total_bill    tip     sex smoker  day    time  size  price_per_person  \
# 92         5.75   1.00  Female    Yes  Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes  Sat  Dinner     1              3.07
# 16        10.33   1.67  Female     No  Sun  Dinner     3              3.44
# 1         10.34   1.66    Male     No  Sun  Dinner     3              3.45
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2              3.62
# ..          ...    ...     ...    ...  ...     ...   ...               ...
# 237       32.83   1.17    Male    Yes  Sat  Dinner     2             16.42
# 175       32.90   3.11    Male    Yes  Sun  Dinner     2             16.45
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 179       34.63   3.55    Male    Yes  Sun  Dinner     2             17.32
# 184       40.55   3.00    Male    Yes  Sun  Dinner     2             20.27
#
#            Payer Name         CC Number Payment ID    tp
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number  \
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000
# tp                 -0.334753  0.343895 -0.141157         -0.313220  -0.027643
#
#                         tp
# total_bill       -0.334753
# tip               0.343895
# size             -0.141157
# price_per_person -0.313220
# CC Number        -0.027643
# tp                1.000000

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.head()
# Out:
# 0    F
# 1    M
# 2    M
# 3    M
# 4    F
# Name: sex, dtype: object

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['sex'].replace('Female','F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %%
df.head()
# Out:
# 0    F
# 1    M
# 2    M
# 3    M
# 4    F
# Name: sex, dtype: object

# %%
df = p.read_csv('/Users/ka53/Desktop/ml/Notebooks ML Rus V10/DATA/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
r = p.DataFrame([1,2,3,3,3,3],['a','b','c','d','e','l'])

# %%
r.duplicated()
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# l     True
# dtype: bool

# %%
r
# Out:
#    0
# a  1
# b  2
# c  3
# d  3
# e  3
# l  3

# %%
r.drop_duplicates()
# Out:
#    0
# a  1
# b  2
# c  3

# %%
df['tip'].between(2,5)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 239    False
# 240     True
# 241     True
# 242    False
# 243     True
# Name: tip, Length: 244, dtype: bool

# %%
df[df['tip'].between(2,5)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.nlargest(5,'tip')
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.nsmallest(5,'tip')
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# 92         Leah Ramirez  3508911676966392    Fri3780
# 111         Terri Jones  3559221007826887    Sat4801
# 236       Matthew Myers  3543676378973965    Sat5032
# 0    Christy Cunningham  3560325168603410    Sun2959

# %%
df.sample(5) # always random 5 columns
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 32        15.06  3.00  Female     No   Sat  Dinner     2              7.53
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2              6.64
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2             10.24
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
#
#          Payer Name        CC Number Payment ID
# 32    Amanda Wilson  213186304291560    Sat1327
# 215    Jessica Owen    4726904879471    Sat6983
# 213  Robin Andersen     580140531089    Sat1374
# 106   Karl Mcdaniel  180024452771522    Sat7865
# 143    Regina Jones    4311048695487   Thur6179
