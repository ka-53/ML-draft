# %%
import numpy as n 
import pandas as p

# %%
url = 'https://en.wikipedia.org/wiki/World_population'

# %%
tables = p.read_html(url)

# %%
pwd
# Out:
# '/Users/ka53/Desktop/ml-practice/pandas/input-output'

# %%
football = p.read_html('/Users/ka53/Desktop/football.html')

# %%
len(football)
# Out:
# 1

# %%
football[0]
# Out:
#       0                                                  1
# 0   NaN                                                NaN
# 1   NaN                                                NaN
# 2   NaN                                    <!DOCTYPE html>
# 3   NaN                                   <html lang="en">
# 4   NaN                                             <head>
# ..   ..                                                ...
# 947 NaN  <!-- End InMobi Choice. Consent Manager Tag v3...
# 948 NaN                                          </footer>
# 949 NaN                                            </body>
# 950 NaN                                            </html>
# 951 NaN                                                NaN
#
# [952 rows x 2 columns]

# %%
tables[0]
# Out:
#     0                                                  1
# 0 NaN  This article contains several duplicated citat...

# %%
len(tables)
# Out:
# 31

# %%
tables[1]
# Out:
#       Population         1     2     3     4     5     6     7     8     9  \
# 0           Year      1804  1927  1960  1974  1987  1999  2011  2022  2037
# 1  Years elapsed  200,000+   123    33    14    13    12    12    11    15
#
#      10
# 0  2057
# 1    20

# %%
ufl = 'https://yflrussia.ru/tournament/1037808/tables'
ufl1 = p.read_html(ufl)

# %%
len(ufl1)
# Out:
# 7

# %%
ufl1[6]
# Out:
#    Игрок          Игрок.1  ЖК  КК
# 0    NaN   Михаил Пыхчеев   5   1
# 1    NaN          Спартак   5   1
# 2    NaN   Тимур Корчагин   3   1
# 3    NaN           Динамо   3   1
# 4    NaN    Михаил Юсупов   3   1
# 5    NaN        Чертаново   3   1
# 6    NaN   Борис Парсегов   3   1
# 7    NaN        Чертаново   3   1
# 8    NaN  Антон Камышенко   3   1
# 9    NaN             Сочи   3   1

# %%
ufl1[3].columns
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
ufl1[0]
# Out:
#     Unnamed: 0   #              Команда             1              2  \
# 0          NaN   1        Академия Сочи           NaN   2 : 0  5 : 0
# 1          NaN   2  Академия футбола КК  0 : 2  0 : 5            NaN
# 2          NaN   3      Академия Алания  0 : 2  1 : 3   1 : 2  1 : 4
# 3          NaN   4             СШ Ротор  0 : 4  0 : 5   1 : 2  2 : 3
# 4          NaN   5           АФ Волгарь  2 : 4  2 : 2   3 : 2  2 : 3
# 5          NaN   6      Динамо-Дагестан  1 : 0  0 : 2   2 : 3  1 : 2
# 6          NaN   7      Спартак–Нальчик  1 : 1  0 : 2   2 : 4  3 : 1
# 7          NaN   8          Динамо–СУОР  1 : 2  1 : 4   2 : 2  1 : 0
# 8          NaN   9  ФК Динамо Махачкала  0 : 6  2 : 2   2 : 1  1 : 2
# 9          NaN  10    ФШ им. Л.Слуцкого  0 : 3  0 : 4   1 : 7  0 : 1
# 10         NaN  11      Академия Рамзан  1 : 2  1 : 2  0 : 10  0 : 1
# 11         NaN  12        СШ Черноморец  1 : 1  0 : 5   0 : 1  0 : 2
# 12         NaN  13       Академия Ротор  1 : 4  1 : 2   0 : 5  1 : 2
# ...

# %%
tables[0]
# Out:
#     0                                                  1
# 0 NaN  This article contains several duplicated citat...

# %%
topten = ufl1[0]
