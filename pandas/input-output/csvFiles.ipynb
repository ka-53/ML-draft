# %%
import numpy as n 
import pandas as p

# %%
pwd
# Out:
# '/Users/ka53/Desktop/ml-practice/pandas'

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/ka53/Desktop/ml-practice/pandas'

# %%
#df = p.read_csv('/Users/ka53/Desktop/ml/Notebooks ML Rus V10/DATA/example.csv')

# %%
df = p.read_csv('/Users/ka53/Downloads/England Football Results.csv',header=None)

# %%
df
# Out:
#      0           1      2            3               4     5     6    7    \
# 0    Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG  FTR
# 1     E0  16/08/2024  20:00   Man United          Fulham     1     0    H
# 2     E0  17/08/2024  12:30      Ipswich       Liverpool     0     2    A
# 3     E0  17/08/2024  15:00      Arsenal          Wolves     2     0    H
# 4     E0  17/08/2024  15:00      Everton        Brighton     0     3    A
# ..   ...         ...    ...          ...             ...   ...   ...  ...
# 96    E0  02/11/2024  15:00  Southampton         Everton     1     0    H
# 97    E0  02/11/2024  17:30       Wolves  Crystal Palace     2     2    D
# 98    E0  03/11/2024  14:00    Tottenham     Aston Villa     4     1    H
# 99    E0  03/11/2024  16:30   Man United         Chelsea     1     1    D
# 100   E0  04/11/2024  20:00       Fulham       Brentford     2     1    H
#
#       8     9    ...       110       111    112    113      114      115  \
# ...

# %%
df = p.read_csv('/Users/ka53/Downloads/England Football Results.csv',)

# %%
df
# Out:
#    Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  16/08/2024  20:00   Man United          Fulham     1     0   H     0
# 1   E0  17/08/2024  12:30      Ipswich       Liverpool     0     2   A     0
# 2   E0  17/08/2024  15:00      Arsenal          Wolves     2     0   H     1
# 3   E0  17/08/2024  15:00      Everton        Brighton     0     3   A     0
# 4   E0  17/08/2024  15:00    Newcastle     Southampton     1     0   H     1
# ..  ..         ...    ...          ...             ...   ...   ...  ..   ...
# 95  E0  02/11/2024  15:00  Southampton         Everton     1     0   H     0
# 96  E0  02/11/2024  17:30       Wolves  Crystal Palace     2     2   D     0
# 97  E0  03/11/2024  14:00    Tottenham     Aston Villa     4     1   H     0
# 98  E0  03/11/2024  16:30   Man United         Chelsea     1     1   D     0
# 99  E0  04/11/2024  20:00       Fulham       Brentford     2     1   H     0
#
# ...

# %%
df.to_csv('/Users/ka53/Desktop/new.csv') # we creat new csv file

# %% [markdown]
# for reading .READ_<CSV>, for creating .TO_<CSV>
