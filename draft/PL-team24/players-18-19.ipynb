# %%
import numpy as n
import pandas as p

# %%
pwd
# Out:
# '/Users/ka53/Desktop/ml-practice/draft/PL-team24'

# %%
df = p.read_csv('/Users/ka53/Downloads/Premier League Players 2018-2019 Stats.csv')

# %%
df.columns
# Out:
# Index(['full_name', 'age', 'birthday', 'birthday_GMT', 'league', 'season',
#        'position', 'Current Club', 'minutes_played_overall',
#        'minutes_played_home',
#        ...
#        'annual_salary_eur_percentile',
#        'clean_sheets_percentage_percentile_overall',
#        'min_per_card_percentile_overall', 'cards_per90_percentile_overall',
#        'booked_over05_overall', 'booked_over05_percentage_overall',
#        'booked_over05_percentage_percentile_overall', 'shirt_number',
#        'annual_salary_gbp', 'annual_salary_usd'],
#       dtype='object', length=277)

# %%
df.head()
# Out:
#          full_name  age   birthday birthday_GMT          league     season  \
# 0  Aaron Cresswell   32  629712000   1989/12/15  Premier League  2018/2019
# 1     Aaron Lennon   35  545554800   1987/04/16  Premier League  2018/2019
# 2       Aaron Mooy   32  653382000   1990/09/15  Premier League  2018/2019
# 3     Aaron Ramsey   31  662198400   1990/12/26  Premier League  2018/2019
# 4       Aaron Rowe   22  968310000   2000/09/07  Premier League  2018/2019
#
#      position       Current Club  minutes_played_overall  minutes_played_home  \
# 0    Defender    West Ham United                    1589                  888
# 1  Midfielder            Burnley                    1217                  487
# 2  Midfielder  Huddersfield Town                    2327                 1190
# 3  Midfielder            Arsenal                    1327                  689
# 4     Forward  Huddersfield Town                      69                   14
#
#    ...  annual_salary_eur_percentile  \
# ...

# %%
df
# Out:
#                   full_name  age   birthday birthday_GMT          league  \
# 0           Aaron Cresswell   32  629712000   1989/12/15  Premier League
# 1              Aaron Lennon   35  545554800   1987/04/16  Premier League
# 2                Aaron Mooy   32  653382000   1990/09/15  Premier League
# 3              Aaron Ramsey   31  662198400   1990/12/26  Premier League
# 4                Aaron Rowe   22  968310000   2000/09/07  Premier League
# ..                      ...  ...        ...          ...             ...
# 565         Youri Tielemans   25  862988400   1997/05/07  Premier League
# 566           Yves Bissouma   26  841388400   1996/08/30  Premier League
# 567        Zechariah Medley   22  962953200   2000/07/07  Premier League
# 568  Zeze  Steven Sessegnon   22  958633200   2000/05/18  Premier League
# 569        Łukasz Fabiański   37  482659200   1985/04/18  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# ...

# %%
df['div'] = None
df
# Out:
#                   full_name  age   birthday birthday_GMT          league  \
# 0           Aaron Cresswell   32  629712000   1989/12/15  Premier League
# 1              Aaron Lennon   35  545554800   1987/04/16  Premier League
# 2                Aaron Mooy   32  653382000   1990/09/15  Premier League
# 3              Aaron Ramsey   31  662198400   1990/12/26  Premier League
# 4                Aaron Rowe   22  968310000   2000/09/07  Premier League
# ..                      ...  ...        ...          ...             ...
# 565         Youri Tielemans   25  862988400   1997/05/07  Premier League
# 566           Yves Bissouma   26  841388400   1996/08/30  Premier League
# 567        Zechariah Medley   22  962953200   2000/07/07  Premier League
# 568  Zeze  Steven Sessegnon   22  958633200   2000/05/18  Premier League
# 569        Łukasz Fabiański   37  482659200   1985/04/18  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# ...

# %%
df
# Out:
#                   full_name  age   birthday birthday_GMT          league  \
# 0           Aaron Cresswell   32  629712000   1989/12/15  Premier League
# 1              Aaron Lennon   35  545554800   1987/04/16  Premier League
# 2                Aaron Mooy   32  653382000   1990/09/15  Premier League
# 3              Aaron Ramsey   31  662198400   1990/12/26  Premier League
# 4                Aaron Rowe   22  968310000   2000/09/07  Premier League
# ..                      ...  ...        ...          ...             ...
# 565         Youri Tielemans   25  862988400   1997/05/07  Premier League
# 566           Yves Bissouma   26  841388400   1996/08/30  Premier League
# 567        Zechariah Medley   22  962953200   2000/07/07  Premier League
# 568  Zeze  Steven Sessegnon   22  958633200   2000/05/18  Premier League
# 569        Łukasz Fabiański   37  482659200   1985/04/18  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# ...

# %%
df.insert(0,'div',None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zb/zdxx2l0s57103ycrdj0qmmkc0000gn/T/ipykernel_15395/2482826967.py in ?()
# ----> 1 df.insert(0,'div',None)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert div, already exists
