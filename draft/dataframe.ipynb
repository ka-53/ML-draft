# %%
import numpy as n
import pandas as p

# %%
pwd
# Out:
# '/Users/ka53/Desktop/ml-practice/draft'

# %%
df = p.read_csv('/Users/ka53/Downloads/England Football Results.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 120 entries, Div to BFECAHA
# dtypes: float64(96), int64(16), object(8)
# memory usage: 93.9+ KB

# %%
df.head(70)
# Out:
#    Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0   E0  16/08/2024  20:00   Man United         Fulham     1     0   H     0
# 1   E0  17/08/2024  12:30      Ipswich      Liverpool     0     2   A     0
# 2   E0  17/08/2024  15:00      Arsenal         Wolves     2     0   H     1
# 3   E0  17/08/2024  15:00      Everton       Brighton     0     3   A     0
# 4   E0  17/08/2024  15:00    Newcastle    Southampton     1     0   H     1
# ..  ..         ...    ...          ...            ...   ...   ...  ..   ...
# 65  E0  05/10/2024  15:00     West Ham        Ipswich     4     1   H     2
# 66  E0  05/10/2024  17:30      Everton      Newcastle     0     0   D     0
# 67  E0  06/10/2024  14:00  Aston Villa     Man United     0     0   D     0
# 68  E0  06/10/2024  14:00      Chelsea  Nott'm Forest     1     1   D     0
# 69  E0  06/10/2024  16:30     Brighton      Tottenham     3     2   H     0
#
# ...

# %%
df.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.550000    1.330000    0.760000    0.590000   14.340000   12.650000
# std      1.225775    1.015586    0.911431    0.712018    5.942859    4.944898
# min      0.000000    0.000000    0.000000    0.000000    3.000000    1.000000
# 25%      1.000000    1.000000    0.000000    0.000000   10.000000    9.000000
# 50%      1.000000    1.000000    1.000000    0.000000   14.000000   12.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.250000   16.000000
# max      5.000000    6.000000    4.000000    2.000000   36.000000   24.000000
#
#               HST         AST          HF          AF  ...    B365CAHH  \
# count  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# mean     5.300000    4.280000   11.560000   11.290000  ...    1.950800
# ...

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82     2.05
# 1  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99     1.88
# 2  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99     1.87
# 3  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83     2.04
# 4  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82     2.05
#
#    BFECAHH  BFECAHA
# 0     1.90     2.08
# ...

# %%
df = df.drop(columns=['BFECAHA','BFECAHH','AvgCAHA','AvgCAHH','MaxCAHA','MaxCAHH','PCAHA','PCAHH','B365CAHA','B365CAHH'])

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365C<2.5 PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  \
# 0  ...      2.30   1.63    2.38      1.66      2.45      1.61      2.37
# 1  ...      3.20   1.37    3.30      1.40      3.38      1.37      3.18
# 2  ...      3.00   1.41    2.98      1.45      3.00      1.42      2.93
# 3  ...      1.97   1.93    1.97      1.95      2.00      1.89      1.96
# 4  ...      2.75   1.46    2.85      1.46      3.05      1.43      2.84
#
#    BFEC>2.5  BFEC<2.5  AHCh
# 0      1.68      2.46 -0.75
# ...

# %%
df = df.drop(columns=['AHCh','BFEC<2.5','BFEC>2.5','AvgC<2.5','AvgC>2.5','MaxC<2.5','MaxC>2.5','PC<2.5','PC>2.5','B365C<2.5'])

# %%
df = df.drop(columns=['B365C>2.5','BFECA','BFECD','BFECH','AvgCA','AvgCD','AvgCH','MaxCA','MaxCD','MaxCH'])

# %%
df = df.drop(columns=['1XBCA','1XBCD','1XBCH','WHCA','WHCD','WHCH','PSCA','PSCD','PSCH','BFCA'])

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF',
#        'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH',
#        'BWD', 'BWA', 'BFH', 'BFD', 'BFA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD',
#        'WHA', '1XBH', '1XBD', '1XBA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD',
#        'AvgA', 'BFEH', 'BFED', 'BFEA', 'B365>2.5', 'B365<2.5', 'P>2.5',
#        'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'BFE>2.5',
#        'BFE<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH',
#        'MaxAHA', 'AvgAHH', 'AvgAHA', 'BFEAHH', 'BFEAHA', 'B365CH', 'B365CD',
#        'B365CA', 'BWCH', 'BWCD', 'BWCA', 'BFCH', 'BFCD'],
#       dtype='object')

# %%
df = df.drop(columns=['BFCD','BFCH','BWCA','B365CA', 'BWCH', 'BWCD','MaxAHA', 'AvgAHH', 'AvgAHA', 'BFEAHH', 'BFEAHA', 'B365CH', 'B365CD','BFE<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH','P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'BFE>2.5','AvgA', 'BFEH', 'BFED', 'BFEA', 'B365>2.5', 'B365<2.5', 'P>2.5','WHA', '1XBH', '1XBD', '1XBA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD','BWD', 'BWA', 'BFH', 'BFD', 'BFA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD','B365H', 'B365D', 'B365A', 'BWH',])

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  ...   5   2  12  10   7   8   2   3   0   0
# 1  ...   2   5   9  18   2  10   3   1   0   0
# 2  ...   6   3  17  14   8   2   2   2   0   0
# 3  ...   1   5   8   8   1   5   1   1   1   0
# 4  ...   1   4  15  16   3  12   2   4   1   0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF',
#        'HC', 'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
df = df.drop(columns=['HTAG','HTHG','HTR'])

# %%
df.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR     Referee  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     R Jones
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A  T Robinson
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H   J Gillett
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A    S Hooper
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H    C Pawson
#
#    HS  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  14  ...    5    2  12  10   7   8   2   3   0   0
# 1   7  ...    2    5   9  18   2  10   3   1   0   0
# 2  18  ...    6    3  17  14   8   2   2   2   0   0
# 3   9  ...    1    5   8   8   1   5   1   1   1   0
# 4   3  ...    1    4  15  16   3  12   2   4   1   0
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns=['Div','HF','AF','AC','HC'])

# %%
df.head()
# Out:
#          Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR     Referee  HS  \
# 0  16/08/2024  20:00  Man United       Fulham     1     0   H     R Jones  14
# 1  17/08/2024  12:30     Ipswich    Liverpool     0     2   A  T Robinson   7
# 2  17/08/2024  15:00     Arsenal       Wolves     2     0   H   J Gillett  18
# 3  17/08/2024  15:00     Everton     Brighton     0     3   A    S Hooper   9
# 4  17/08/2024  15:00   Newcastle  Southampton     1     0   H    C Pawson   3
#
#    AS  HST  AST  HY  AY  HR  AR
# 0  10    5    2   2   3   0   0
# 1  18    2    5   3   1   0   0
# 2   9    6    3   2   2   0   0
# 3  10    1    5   1   1   1   0
# 4  19    1    4   2   4   1   0

# %%
df = df.set_index('HomeTeam')

# %%
df.head()
# Out:
#                   Date   Time     AwayTeam  FTHG  FTAG FTR     Referee  HS  \
# HomeTeam
# Man United  16/08/2024  20:00       Fulham     1     0   H     R Jones  14
# Ipswich     17/08/2024  12:30    Liverpool     0     2   A  T Robinson   7
# Arsenal     17/08/2024  15:00       Wolves     2     0   H   J Gillett  18
# Everton     17/08/2024  15:00     Brighton     0     3   A    S Hooper   9
# Newcastle   17/08/2024  15:00  Southampton     1     0   H    C Pawson   3
#
#             AS  HST  AST  HY  AY  HR  AR
# HomeTeam
# Man United  10    5    2   2   3   0   0
# Ipswich     18    2    5   3   1   0   0
# Arsenal      9    6    3   2   2   0   0
# Everton     10    1    5   1   1   1   0
# Newcastle   19    1    4   2   4   1   0

# %%
df.loc['Man City']
# Out:
#                 Date   Time     AwayTeam  FTHG  FTAG FTR       Referee  HS  \
# HomeTeam
# Man City  24/08/2024  15:00      Ipswich     4     1   H   M Salisbury  14
# Man City  14/09/2024  15:00    Brentford     2     1   H        D Bond  18
# Man City  22/09/2024  16:30      Arsenal     2     2   D      M Oliver  33
# Man City  05/10/2024  15:00       Fulham     3     2   H      P Bankes  20
# Man City  26/10/2024  15:00  Southampton     1     0   H  T Harrington  22
#
#           AS  HST  AST  HY  AY  HR  AR
# HomeTeam
# Man City   1    5    1   2   3   0   0
# Man City   8    7    5   3   1   0   0
# Man City   5   11    3   3   4   0   1
# Man City  11    7    4   2   1   0   0
# Man City   5    8    2   1   3   0   0

# %%
df = df.reset_index('HomeTeam')

# %%
df.head()
# Out:
#      HomeTeam        Date   Time     AwayTeam  FTHG  FTAG FTR     Referee  HS  \
# 0  Man United  16/08/2024  20:00       Fulham     1     0   H     R Jones  14
# 1     Ipswich  17/08/2024  12:30    Liverpool     0     2   A  T Robinson   7
# 2     Arsenal  17/08/2024  15:00       Wolves     2     0   H   J Gillett  18
# 3     Everton  17/08/2024  15:00     Brighton     0     3   A    S Hooper   9
# 4   Newcastle  17/08/2024  15:00  Southampton     1     0   H    C Pawson   3
#
#    AS  HST  AST  HY  AY  HR  AR
# 0  10    5    2   2   3   0   0
# 1  18    2    5   3   1   0   0
# 2   9    6    3   2   2   0   0
# 3  10    1    5   1   1   1   0
# 4  19    1    4   2   4   1   0

# %%
df.columns
# Out:
# Index(['HomeTeam', 'Date', 'Time', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'Referee', 'HS', 'AS', 'HST', 'AST', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
df = df.rename(columns={
    'FTHG': 'Goals H',
    'FTAG': 'Goals A',
    'FTR': 'Result',
    'HS': 'Shoots H',
    'AS': 'Shoots A',
    'HST': 'Target H',
    'AST': 'Target A',
    'HY': 'Yellow H',
    'AY': 'Yellow A',
    'HR': 'Red H',
    'AR': 'Red A'
})

# %%
df.head()
# Out:
#      HomeTeam        Date   Time     AwayTeam  Goals H  Goals A Result  \
# 0  Man United  16/08/2024  20:00       Fulham        1        0      H
# 1     Ipswich  17/08/2024  12:30    Liverpool        0        2      A
# 2     Arsenal  17/08/2024  15:00       Wolves        2        0      H
# 3     Everton  17/08/2024  15:00     Brighton        0        3      A
# 4   Newcastle  17/08/2024  15:00  Southampton        1        0      H
#
#       Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 0     R Jones        14        10         5         2         2         3
# 1  T Robinson         7        18         2         5         3         1
# 2   J Gillett        18         9         6         3         2         2
# 3    S Hooper         9        10         1         5         1         1
# 4    C Pawson         3        19         1         4         2         4
#
#    Red H  Red A
# 0      0      0
# 1      0      0
# 2      0      0
# 3      1      0
# ...

# %%
df[df['Shoots H'] > 15]
# Out:
#           HomeTeam        Date   Time        AwayTeam  Goals H  Goals A  \
# 2          Arsenal  17/08/2024  15:00          Wolves        2        0
# 12          Fulham  24/08/2024  15:00       Leicester        2        1
# 17     Bournemouth  25/08/2024  14:00       Newcastle        1        1
# 19       Liverpool  25/08/2024  16:30       Brentford        2        0
# 21       Brentford  31/08/2024  15:00     Southampton        3        1
# 22         Everton  31/08/2024  15:00     Bournemouth        2        3
# 25   Nott'm Forest  31/08/2024  15:00          Wolves        1        1
# 31        Brighton  14/09/2024  15:00         Ipswich        0        0
# 32  Crystal Palace  14/09/2024  15:00       Leicester        2        2
# 33          Fulham  14/09/2024  15:00        West Ham        1        1
# 35        Man City  14/09/2024  15:00       Brentford        2        1
# 36     Aston Villa  14/09/2024  17:30         Everton        3        2
# ...

# %%
df[(df['Shoots H'] > 15) & (df['Shoots A'] > 15)]
# Out:
#          HomeTeam        Date   Time        AwayTeam  Goals H  Goals A Result  \
# 21      Brentford  31/08/2024  15:00     Southampton        3        1      H
# 22        Everton  31/08/2024  15:00     Bournemouth        2        3      A
# 44      Liverpool  21/09/2024  15:00     Bournemouth        3        0      H
# 62      Brentford  05/10/2024  15:00          Wolves        5        3      H
# 68        Chelsea  06/10/2024  14:00   Nott'm Forest        1        1      D
# 79  Nott'm Forest  21/10/2024  20:00  Crystal Palace        1        0      H
#
#          Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 21       J Smith        20        18         7         6         2         1
# 22     S Attwell        18        17         8         7         2         1
# 44  T Harrington        19        19        13         6         1         4
# 62      A Madley        19        17        12         6         2         3
# ...

# %%
df.head()
# Out:
#      HomeTeam        Date   Time     AwayTeam  Goals H  Goals A Result  \
# 0  Man United  16/08/2024  20:00       Fulham        1        0      H
# 1     Ipswich  17/08/2024  12:30    Liverpool        0        2      A
# 2     Arsenal  17/08/2024  15:00       Wolves        2        0      H
# 3     Everton  17/08/2024  15:00     Brighton        0        3      A
# 4   Newcastle  17/08/2024  15:00  Southampton        1        0      H
#
#       Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 0     R Jones        14        10         5         2         2         3
# 1  T Robinson         7        18         2         5         3         1
# 2   J Gillett        18         9         6         3         2         2
# 3    S Hooper         9        10         1         5         1         1
# 4    C Pawson         3        19         1         4         2         4
#
#    Red H  Red A
# 0      0      0
# 1      0      0
# 2      0      0
# 3      1      0
# ...

# %%
def goals(num,num1):
    return num + num1

# %%
goals(1,1)
# Out:
# 2

# %%
df['all goals'] = df[['Goals H', 'Goals A']].apply(lambda row: goals(row['Goals H'], row['Goals A']), axis=1)

# %%
df.head(15)
# Out:
#           HomeTeam        Date   Time        AwayTeam  Goals H  Goals A  \
# 0       Man United  16/08/2024  20:00          Fulham        1        0
# 1          Ipswich  17/08/2024  12:30       Liverpool        0        2
# 2          Arsenal  17/08/2024  15:00          Wolves        2        0
# 3          Everton  17/08/2024  15:00        Brighton        0        3
# 4        Newcastle  17/08/2024  15:00     Southampton        1        0
# 5    Nott'm Forest  17/08/2024  15:00     Bournemouth        1        1
# 6         West Ham  17/08/2024  17:30     Aston Villa        1        2
# 7        Brentford  18/08/2024  14:00  Crystal Palace        2        1
# 8          Chelsea  18/08/2024  16:30        Man City        0        2
# 9        Leicester  19/08/2024  20:00       Tottenham        1        1
# 10        Brighton  24/08/2024  12:30      Man United        2        1
# 11  Crystal Palace  24/08/2024  15:00        West Ham        0        2
# ...

# %%
df[df['all goals'] > 5]
# Out:
#      HomeTeam        Date   Time   AwayTeam  Goals H  Goals A Result  \
# 18     Wolves  25/08/2024  14:00    Chelsea        2        6      A
# 51    Arsenal  28/09/2024  15:00  Leicester        4        2      H
# 53    Chelsea  28/09/2024  15:00   Brighton        4        2      H
# 62  Brentford  05/10/2024  15:00     Wolves        5        3      H
# 82  Brentford  26/10/2024  15:00    Ipswich        4        3      H
#
#       Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 18  D England        12        14         4         8         2         3
# 51  S Barrott        36         5        16         3         2         4
# 53   P Bankes        15        15         7         5         3         2
# 62   A Madley        19        17        12         6         2         3
# 82    L Smith        20        11         9         5         0         1
#
#     Red H  Red A  all goals
# 18      0      0          8
# 51      0      0          6
# ...

# %%
df.tail()
# Out:
#        HomeTeam        Date   Time        AwayTeam  Goals H  Goals A Result  \
# 95  Southampton  02/11/2024  15:00         Everton        1        0      H
# 96       Wolves  02/11/2024  17:30  Crystal Palace        2        2      D
# 97    Tottenham  03/11/2024  14:00     Aston Villa        4        1      H
# 98   Man United  03/11/2024  16:30         Chelsea        1        1      D
# 99       Fulham  04/11/2024  20:00       Brentford        2        1      H
#
#       Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 95   A Madley         9        16         2         5         4         2
# 96   A Taylor        11        19         6         7         1         2
# 97   C Pawson        16        12         6         1         2         0
# 98    R Jones        11        12         4         3         6         2
# 99  S Attwell        26         5        12         2         2         1
#
#     Red H  Red A  all goals
# 95      0      0          1
# ...

# %%
nd =  {
    "HomeTeam": ["Wolves"],
    "Date": ["09/11/2024"],
    "Time": ["16:00"],
    "AwayTeam": ["Southampton"],
    "Goals H": [2],
    "Goals A": [0],
    "Result": ["H"],
    "Referee": ["T Bramall"],
    "Shoots H": [8],
    "Shoots A": [9],
    "Target H": [4],
    "Target A": [0],
    "Yellow H": [1],
    "Yellow A": [4],
    "Red H": [0],
    "Red A": [0],
    "all goals": [2]
}

# %%
nd = p.DataFrame(nd)

df = p.concat([df,nd], ignore_index=True)

# %%
df.tail()
# Out:
#        HomeTeam        Date   Time        AwayTeam  Goals H  Goals A Result  \
# 96       Wolves  02/11/2024  17:30  Crystal Palace        2        2      D
# 97    Tottenham  03/11/2024  14:00     Aston Villa        4        1      H
# 98   Man United  03/11/2024  16:30         Chelsea        1        1      D
# 99       Fulham  04/11/2024  20:00       Brentford        2        1      H
# 100      Wolves  09/11/2024  16:00     Southampton        2        0      H
#
#        Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 96    A Taylor        11        19         6         7         1         2
# 97    C Pawson        16        12         6         1         2         0
# 98     R Jones        11        12         4         3         6         2
# 99   S Attwell        26         5        12         2         2         1
# 100  T Bramall         8         9         4         0         1         4
#
#      Red H  Red A  all goals
# ...

# %%
nd = {
    "HomeTeam": ["Crystal Palace", "West Ham","Brentford","Brighton","Liverpool","Nott'm Forest","Tottenham","Man United","Chelsea"],
    "Date": ["09/11/2024", "09/11/2024", "09/11/2024", "09/11/2024","09/11/2024","10/11/2024","10/11/2024","10/11/2024"],
    "Time": ["16:00", "16:00","16:00","18:30","21:00","15:00","15:00","15:00","17:30"],
    "AwayTeam": ["Fulham", "Everton","Bournemouth","Man City","Aston Villa","Newcastle","Ipswich","Leicester","Arsenal"],
    "Goals H": [0, 0, 3, 2, 2, 1, 1, 3, 1],
    "Goals A": [2, 0, 2, 1, 0, 3, 2, 0, 1],
    "Result": ["A", "D", "H", "H", "H", "A", "A", "H", "D"],
    "Referee": ["M Solberi", "S Attwell", "D Bond", "S Barrott", "D Kut", "A Taylor", "D England","P Bankes","M Oliver"],
    "Shoots H": [13, 11, 12, 10, 14, 9, 17, 13, 17],
    "Shoots A": [17, 18, 15, 15, 12, 17, 8, 6, 13],
    "Target H": [5, 6, 6, 4, 5, 3, 5, 3, 3],
    "Target A": [7, 4, 3, 6, 2, 6, 3, 5, 3],
    "Yellow H": [1, 1, 2, 3, 0, 1, 1, 0, 4],
    "Yellow A": [1, 2, 4, 3, 3, 1, 5, 1, 2],
    "Red H": [1, 0, 0, 0, 0, 0, 0, 0, 0],
    "Red A": [0, 0, 0, 0, 0, 0, 0, 0, 0],
    "all goals": [2, 0, 5, 3, 2, 4, 3, 3, 2]

}

# %%
df.head()
# Out:
#      HomeTeam        Date   Time     AwayTeam  Goals H  Goals A Result  \
# 0  Man United  16/08/2024  20:00       Fulham        1        0      H
# 1     Ipswich  17/08/2024  12:30    Liverpool        0        2      A
# 2     Arsenal  17/08/2024  15:00       Wolves        2        0      H
# 3     Everton  17/08/2024  15:00     Brighton        0        3      A
# 4   Newcastle  17/08/2024  15:00  Southampton        1        0      H
#
#       Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 0     R Jones        14        10         5         2         2         3
# 1  T Robinson         7        18         2         5         3         1
# 2   J Gillett        18         9         6         3         2         2
# 3    S Hooper         9        10         1         5         1         1
# 4    C Pawson         3        19         1         4         2         4
#
#    Red H  Red A  all goals
# 0      0      0          1
# 1      0      0          2
# ...

# %%
nd = p.DataFrame(nd)

df = p.concat([df,nd], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 nd = p.DataFrame(nd)
#       3 df = p.concat([df,nd], ignore_index=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
nd = {
    "HomeTeam": ["Crystal Palace", "West Ham", "Brentford", "Brighton", "Liverpool", "Nott'm Forest", "Tottenham", "Man United", "Chelsea"],
    "Date": ["09/11/2024", "09/11/2024", "09/11/2024", "09/11/2024", "09/11/2024", "10/11/2024", "10/11/2024", "10/11/2024", "10/11/2024"],
    "Time": ["16:00", "16:00", "16:00", "18:30", "21:00", "15:00", "15:00", "15:00", "17:30"],
    "AwayTeam": ["Fulham", "Everton", "Bournemouth", "Man City", "Aston Villa", "Newcastle", "Ipswich", "Leicester", "Arsenal"],
    "Goals H": [0, 0, 3, 2, 2, 1, 1, 3, 1],
    "Goals A": [2, 0, 2, 1, 0, 3, 2, 0, 1],
    "Result": ["A", "D", "H", "H", "H", "A", "A", "H", "D"],
    "Referee": ["M Solberi", "S Attwell", "D Bond", "S Barrott", "D Kut", "A Taylor", "D England", "P Bankes", "M Oliver"],
    "Shoots H": [13, 11, 12, 10, 14, 9, 17, 13, 17],
    "Shoots A": [17, 18, 15, 15, 12, 17, 8, 6, 13],
    "Target H": [5, 6, 6, 4, 5, 3, 5, 3, 3],
    "Target A": [7, 4, 3, 6, 2, 6, 3, 5, 3],
    "Yellow H": [1, 1, 2, 3, 0, 1, 1, 0, 4],
    "Yellow A": [1, 2, 4, 3, 3, 1, 5, 1, 2],
    "Red H": [1, 0, 0, 0, 0, 0, 0, 0, 0],
    "Red A": [0, 0, 0, 0, 0, 0, 0, 0, 0],
    "all goals": [2, 0, 5, 3, 2, 4, 3, 3, 2]
}

# Создаем DataFrame из исправленного словаря
nd = p.DataFrame(nd)

# Объединяем с исходным DataFrame (df)
df = p.concat([df, nd], ignore_index=True)

# %%
df.tail()
# Out:
#           HomeTeam        Date   Time     AwayTeam  Goals H  Goals A Result  \
# 105      Liverpool  09/11/2024  21:00  Aston Villa        2        0      H
# 106  Nott'm Forest  10/11/2024  15:00    Newcastle        1        3      A
# 107      Tottenham  10/11/2024  15:00      Ipswich        1        2      A
# 108     Man United  10/11/2024  15:00    Leicester        3        0      H
# 109        Chelsea  10/11/2024  17:30      Arsenal        1        1      D
#
#        Referee  Shoots H  Shoots A  Target H  Target A  Yellow H  Yellow A  \
# 105      D Kut        14        12         5         2         0         3
# 106   A Taylor         9        17         3         6         1         1
# 107  D England        17         8         5         3         1         5
# 108   P Bankes        13         6         3         5         0         1
# 109   M Oliver        17        13         3         3         4         2
#
#      Red H  Red A  all goals
# ...
